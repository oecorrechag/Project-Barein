# %% [markdown]
# # Project 02

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
# Carga data
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Proyectos/Bahrein/data.xlsx')
df.head()
# Out:
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    536365    85123A  ...    17850.0  United Kingdom
# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
# 4    536365    84029E  ...    17850.0  United Kingdom
#
# [5 rows x 8 columns]

# %%
df.shape
# Out:
# (541909, 8)

# %%
# Eliminar clave primaria que inicia con C
df['Description'] = df['Description'].str.strip()
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
df['InvoiceNo'] = df['InvoiceNo'].astype('str')
df = df[~df['InvoiceNo'].str.contains('C')]
df.head()
# Out:
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    536365    85123A  ...    17850.0  United Kingdom
# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
# 4    536365    84029E  ...    17850.0  United Kingdom
#
# [5 rows x 8 columns]

# %%
df['Country'].unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Finland',
#        'Austria', 'Bahrain', 'Israel', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
# canasta Suiza
basket = (df[df['Country'] =="Netherlands"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))
basket.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  ...  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo                            ...
# 536403                          0.0  ...                               0.0
# 539491                          0.0  ...                               0.0
# 539731                          0.0  ...                               0.0
# 541206                          0.0  ...                               0.0
# 541570                          0.0  ...                               0.0
#
# [5 rows x 803 columns]

# %%
basket.shape
# Out:
# (95, 803)

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

basket_sets = basket.applymap(encode_units)
basket_sets.drop('POSTAGE', inplace=True, axis=1)

# %%
basket_sets.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  ...  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo                            ...
# 536403                            0  ...                                 0
# 539491                            0  ...                                 0
# 539731                            0  ...                                 0
# 541206                            0  ...                                 0
# 541570                            0  ...                                 0
#
# [5 rows x 802 columns]

# %% [markdown]
# # Aplicar apriori

# %%
frequent_itemsets = apriori(basket_sets, min_support=0.07, use_colnames=True)

# %%
frequent_itemsets.head()
# Out:
#     support                             itemsets
# 0  0.073684         (3 HOOK HANGER MAGIC GARDEN)
# 1  0.073684           (36 FOIL HEART CAKE CASES)
# 2  0.073684  (5 HOOK HANGER RED MAGIC TOADSTOOL)
# 3  0.105263     (72 SWEETHEART FAIRY CAKE CASES)
# 4  0.073684         (BREAD BIN DINER STYLE PINK)

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules.head()
# Out:
#                            antecedents  ... conviction
# 0     (72 SWEETHEART FAIRY CAKE CASES)  ...   7.684211
# 1               (DOLLY GIRL LUNCH BOX)  ...   1.514170
# 2     (72 SWEETHEART FAIRY CAKE CASES)  ...   2.736842
# 3  (ROUND SNACK BOXES SET OF 4 FRUITS)  ...   1.521053
# 4     (72 SWEETHEART FAIRY CAKE CASES)  ...   2.456140
#
# [5 rows x 9 columns]

# %%
rules.sort_values(by=['confidence'], ascending=False)
# Out:
#                                             antecedents  ... conviction
# 1679  (SPACEBOY LUNCH BOX, PLASTERS IN TIN SPACEBOY,...  ...        inf
# 422   (COWBOYS AND INDIANS BIRTHDAY CARD, PLASTERS I...  ...        inf
# 801   (PLASTERS IN TIN SPACEBOY, LUNCH BAG RED RETRO...  ...        inf
# 358   (72 SWEETHEART FAIRY CAKE CASES, ROUND SNACK B...  ...        inf
# 1034  (PLASTERS IN TIN SPACEBOY, STRAWBERRY LUNCH BO...  ...        inf
# ...                                                 ...  ...        ...
# 515                                (SPACEBOY LUNCH BOX)  ...   1.235088
# 899                                (SPACEBOY LUNCH BOX)  ...   1.221053
# 236                                (SPACEBOY LUNCH BOX)  ...   1.192982
# 510                                (SPACEBOY LUNCH BOX)  ...   1.235088
# 390                                (SPACEBOY LUNCH BOX)  ...   1.235088
#
# [1838 rows x 9 columns]
